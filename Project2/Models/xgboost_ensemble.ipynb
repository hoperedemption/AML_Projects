# %%
import pandas as pd 
import numpy as np

from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import ADASYN

# %%
data_train = pd.read_csv('features_extracted_more.csv', index_col='id')

# %%
X, y = data_train.drop(columns=['y']), data_train['y']

# %%
X_ = X.replace(to_replace=np.inf, value=np.nan)

# %%
imputer = KNNImputer(n_neighbors=5, weights='distance')
X_imputed = imputer.fit_transform(X_)

# %%
def filter_multicolinearity(X_train, sigma): 
    corr_matrix = np.triu(np.corrcoef(X_train, rowvar=False))
    np.fill_diagonal(corr_matrix, val=0)
    mask_multicorr = (corr_matrix < sigma).all(axis=1)
    return mask_multicorr

# %%
mask_multicorr = filter_multicolinearity(X_imputed, 0.95)

# %%
X_columns = X.columns 
multi_colinear_columns = X_columns[~mask_multicorr]

# %%
multi_colinear_columns
# Out:
# Index(['HeartRatem', 'RRmean', 'mean_nni', 'sdnn', 'sdsd', 'rmssd',
#        'range_nni', 'ratio_sd2_sd1', 'HRV_MeanNN', 'HRV_SDNN', 'HRV_RMSSD',
#        'HRV_SDSD', 'HRV_CVNN', 'HRV_CVSD', 'HRV_MadNN', 'HRV_SDRMSSD',
#        'HRV_SD1', 'HRV_SD2', 'HRV_PIP', 'HRV_GI', 'HRV_SI', 'HRV_SD1d',
#        'HRV_SD2d', 'HRV_SD2a', 'HRV_SDNNd', 'HRV_MFDFA_alpha1_Fluctuation',
#        'HRV_CMSEn'],
#       dtype='object')

# %%
X_filtered_multicorr = X_.loc[:, mask_multicorr]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_filtered_multicorr, y, test_size=0.2, shuffle=True)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, shuffle=True)

# %%
import xgboost as xgb 
from xgboost import XGBClassifier

from sklearn.metrics import f1_score
from imblearn.over_sampling import RandomOverSampler

# tree_method : hist vs approx
# max depth: 3-12
# min_child_weight: [1, 200]
# subsample: [0.7, 1.0]
#  colsample_bylevel: [0.5, 1]
# reg_lambda = [0, 10] or reg_alpha = [0, 10]
# learning_rate = [0, 1]
# num_boost_round = N
# early_stopping_rounds: how many non improved boosting rounds until stop training

learning_rate = 0.3

xgboost_classification_model = XGBClassifier(n_estimators=1000, objective='multi:softprob', \
    eval_metric='auc', early_stopping_rounds=50, n_jobs=-1)

X_train, y_train = RandomOverSampler().fit_resample(X_train, y_train)
xgboost_classification_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=0)
y_pred = xgboost_classification_model.predict(X_val)

# %%
import optuna
import time

def objective(trial):
    params = {
        'tree_method': trial.suggest_categorical('tree_method', ['approx', 'hist']), 
        'max_depth': trial.suggest_int('max_depth', 3, 12), 
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 250), 
        'subsample': trial.suggest_float('colsample_bynode', 0.1, 1.0), 
        'reg_lambda': trial.suggest_float('reg_lambda', 0.001, 25, log=True), 
        'learning_rate': learning_rate
    }
    
    model = xgboost_classification_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=0)
    return f1_score(y_val, model.predict(X_val), average='micro')


sampler = optuna.samplers.TPESampler(seed=42)
study = optuna.create_study(direction='maximize', sampler=sampler)

tic = time.time()
while time.time() - tic < 300:
    study.optimize(objective, n_trials=1)
# Out:
# [I 2024-11-20 20:47:22,529] A new study created in memory with name: no-name-d7dfecce-080b-4691-b004-4422a1e048b7
# [I 2024-11-20 20:47:30,891] Trial 0 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 10, 'min_child_weight': 150, 'colsample_bynode': 0.24041677639819287, 'reg_lambda': 0.004853494503398151}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:47:35,966] Trial 1 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 9, 'min_child_weight': 178, 'colsample_bynode': 0.1185260448662222, 'reg_lambda': 18.43339560109507}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:47:39,992] Trial 2 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 4, 'min_child_weight': 46, 'colsample_bynode': 0.373818018663584, 'reg_lambda': 0.20316425758330103}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:47:44,509] Trial 3 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 9, 'min_child_weight': 35, 'colsample_bynode': 0.3629301836816964, 'reg_lambda': 0.04085426562674716}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:47:48,376] Trial 4 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 4, 'min_child_weight': 129, 'colsample_bynode': 0.6331731119758383, 'reg_lambda': 0.0016006122210857569}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:47:51,594] Trial 5 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 3, 'min_child_weight': 238, 'colsample_bynode': 0.9690688297671034, 'reg_lambda': 3.5915592896588993}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:47:56,191] Trial 6 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 9, 'min_child_weight': 111, 'colsample_bynode': 0.20983441136030095, 'reg_lambda': 0.15057689739420463}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:00,631] Trial 7 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 5, 'min_child_weight': 166, 'colsample_bynode': 0.3805399684804699, 'reg_lambda': 0.19374386425624052}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:04,455] Trial 8 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 12, 'min_child_weight': 194, 'colsample_bynode': 0.9455490474077702, 'reg_lambda': 8.617811795628572}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:07,932] Trial 9 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 3, 'min_child_weight': 49, 'colsample_bynode': 0.14070456001948428, 'reg_lambda': 0.026963935381983883}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:12,238] Trial 10 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 12, 'min_child_weight': 94, 'colsample_bynode': 0.6758183738140613, 'reg_lambda': 0.0011683805147255691}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:16,123] Trial 11 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 9, 'min_child_weight': 194, 'colsample_bynode': 0.13234468202193284, 'reg_lambda': 23.958828668153973}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:19,853] Trial 12 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 7, 'min_child_weight': 165, 'colsample_bynode': 0.28571685674470126, 'reg_lambda': 1.8283154433263142}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:24,309] Trial 13 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 10, 'min_child_weight': 250, 'colsample_bynode': 0.5092919381381499, 'reg_lambda': 0.008765841081237728}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:29,205] Trial 14 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 11, 'min_child_weight': 147, 'colsample_bynode': 0.2518299599179536, 'reg_lambda': 1.2124700813972054}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:32,562] Trial 15 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 7, 'min_child_weight': 84, 'colsample_bynode': 0.4524254602508449, 'reg_lambda': 0.006350054392286954}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:36,537] Trial 16 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 8, 'min_child_weight': 204, 'colsample_bynode': 0.13376664736231875, 'reg_lambda': 0.49380394940926264}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:40,474] Trial 17 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 6, 'min_child_weight': 163, 'colsample_bynode': 0.8272594310024478, 'reg_lambda': 0.03859417554462454}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:44,273] Trial 18 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 10, 'min_child_weight': 219, 'colsample_bynode': 0.26887572998495224, 'reg_lambda': 0.004268667118956601}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:48,554] Trial 19 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 11, 'min_child_weight': 12, 'colsample_bynode': 0.6310196128700969, 'reg_lambda': 15.111153642096552}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:52,212] Trial 20 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 8, 'min_child_weight': 122, 'colsample_bynode': 0.19826041506790965, 'reg_lambda': 0.01945436335838466}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:48:56,303] Trial 21 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 6, 'min_child_weight': 68, 'colsample_bynode': 0.358103875257542, 'reg_lambda': 0.18597860923377152}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:00,562] Trial 22 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 10, 'min_child_weight': 4, 'colsample_bynode': 0.44201913628799405, 'reg_lambda': 0.08573993648896155}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:04,331] Trial 23 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 5, 'min_child_weight': 140, 'colsample_bynode': 0.3050872737241172, 'reg_lambda': 0.5745856264609863}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:07,724] Trial 24 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 8, 'min_child_weight': 183, 'colsample_bynode': 0.18654097023648042, 'reg_lambda': 6.2544845323886005}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:11,629] Trial 25 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 11, 'min_child_weight': 101, 'colsample_bynode': 0.1026509739840805, 'reg_lambda': 0.002492183837664478}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:15,438] Trial 26 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 9, 'min_child_weight': 68, 'colsample_bynode': 0.4380707827273272, 'reg_lambda': 0.6394381007736408}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:19,849] Trial 27 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 6, 'min_child_weight': 143, 'colsample_bynode': 0.5652734173068905, 'reg_lambda': 0.01424545997678273}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:24,706] Trial 28 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 4, 'min_child_weight': 222, 'colsample_bynode': 0.32218918875174213, 'reg_lambda': 2.748931423501493}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:28,821] Trial 29 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 9, 'min_child_weight': 38, 'colsample_bynode': 0.23223298385272526, 'reg_lambda': 0.04763916277330459}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:33,781] Trial 30 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 10, 'min_child_weight': 183, 'colsample_bynode': 0.3777114661765338, 'reg_lambda': 0.06442548061138914}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:37,656] Trial 31 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 9, 'min_child_weight': 24, 'colsample_bynode': 0.35038802731390556, 'reg_lambda': 0.0028829209292214023}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:41,364] Trial 32 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 8, 'min_child_weight': 48, 'colsample_bynode': 0.18427223849224295, 'reg_lambda': 0.010640712877703415}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:45,370] Trial 33 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 7, 'min_child_weight': 28, 'colsample_bynode': 0.40477118182948574, 'reg_lambda': 0.1151783695342822}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:49,992] Trial 34 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 3, 'min_child_weight': 124, 'colsample_bynode': 0.5074724922711218, 'reg_lambda': 0.3106561544052952}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:54,297] Trial 35 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 10, 'min_child_weight': 75, 'colsample_bynode': 0.2577374225493748, 'reg_lambda': 0.0020858058925464175}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:49:58,751] Trial 36 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 11, 'min_child_weight': 53, 'colsample_bynode': 0.3163259790877919, 'reg_lambda': 0.027693847263836672}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:50:02,414] Trial 37 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 9, 'min_child_weight': 153, 'colsample_bynode': 0.18499127995982262, 'reg_lambda': 5.648822895869839}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:50:06,606] Trial 38 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 5, 'min_child_weight': 113, 'colsample_bynode': 0.10076048622584396, 'reg_lambda': 0.0011129942446295481}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:50:11,410] Trial 39 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 12, 'min_child_weight': 102, 'colsample_bynode': 0.7578998707846138, 'reg_lambda': 1.2177518998742856}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:50:21,728] Trial 40 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 4, 'min_child_weight': 174, 'colsample_bynode': 0.49033498099116873, 'reg_lambda': 0.005637064283745404}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:50:37,126] Trial 41 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 4, 'min_child_weight': 153, 'colsample_bynode': 0.5729878162855, 'reg_lambda': 0.0022026501124025473}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:50:40,528] Trial 42 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 3, 'min_child_weight': 139, 'colsample_bynode': 0.6602089419019065, 'reg_lambda': 0.0010127723948430251}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:50:54,353] Trial 43 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 4, 'min_child_weight': 130, 'colsample_bynode': 0.7161696490296572, 'reg_lambda': 0.003988428545900206}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:51:03,927] Trial 44 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 5, 'min_child_weight': 163, 'colsample_bynode': 0.8323645110149741, 'reg_lambda': 0.008704520233392892}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:51:19,080] Trial 45 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 10, 'min_child_weight': 90, 'colsample_bynode': 0.5980406396520506, 'reg_lambda': 0.01779958156994999}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:51:22,778] Trial 46 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 3, 'min_child_weight': 192, 'colsample_bynode': 0.1525184717095719, 'reg_lambda': 0.2954923053328713}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:51:32,665] Trial 47 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 9, 'min_child_weight': 115, 'colsample_bynode': 0.41888091103142666, 'reg_lambda': 11.619344792913207}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:51:43,943] Trial 48 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 7, 'min_child_weight': 21, 'colsample_bynode': 0.23159047831619423, 'reg_lambda': 24.56921742397498}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:51:48,612] Trial 49 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 8, 'min_child_weight': 202, 'colsample_bynode': 0.15572593337660895, 'reg_lambda': 0.001667452079694716}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:51:52,215] Trial 50 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 11, 'min_child_weight': 60, 'colsample_bynode': 0.48201566238623605, 'reg_lambda': 0.0035528959104520336}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:51:55,664] Trial 51 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 3, 'min_child_weight': 244, 'colsample_bynode': 0.9818877062022873, 'reg_lambda': 3.0585161652630006}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:51:59,377] Trial 52 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 4, 'min_child_weight': 226, 'colsample_bynode': 0.8552003369640081, 'reg_lambda': 14.505882268504626}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:52:02,351] Trial 53 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 5, 'min_child_weight': 242, 'colsample_bynode': 0.779238877020077, 'reg_lambda': 5.315284818256563}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:52:05,600] Trial 54 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 3, 'min_child_weight': 133, 'colsample_bynode': 0.8745854675561267, 'reg_lambda': 1.4717373856674463}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:52:08,941] Trial 55 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 4, 'min_child_weight': 207, 'colsample_bynode': 0.9484095872318659, 'reg_lambda': 3.292368882776259}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:52:12,319] Trial 56 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 6, 'min_child_weight': 39, 'colsample_bynode': 0.9082630182304265, 'reg_lambda': 8.092721995500282}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:52:15,942] Trial 57 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'hist', 'max_depth': 10, 'min_child_weight': 174, 'colsample_bynode': 0.2802356341127856, 'reg_lambda': 0.14164191754508274}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:52:19,681] Trial 58 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 9, 'min_child_weight': 152, 'colsample_bynode': 0.2194989532953133, 'reg_lambda': 0.7319018759908931}. Best is trial 0 with value: 0.7975609756097561.
# [I 2024-11-20 20:52:23,116] Trial 59 finished with value: 0.7975609756097561 and parameters: {'tree_method': 'approx', 'max_depth': 8, 'min_child_weight': 11, 'colsample_bynode': 0.5364738659218842, 'reg_lambda': 0.026436851241232965}. Best is trial 0 with value: 0.7975609756097561.

# %%
study.best_trial.params
# Out:
# {'tree_method': 'hist',
#  'max_depth': 10,
#  'min_child_weight': 150,
#  'colsample_bynode': 0.24041677639819287,
#  'reg_lambda': 0.004853494503398151}

# %%
X_train, X_val, y_train, y_val = train_test_split(X_filtered_multicorr, y, test_size=0.2)

# %%
X_train, y_train = RandomOverSampler().fit_resample(X_train, y_train)

# %%
xgboost_classification_model = XGBClassifier(n_estimators=2000, tree_method='hist', max_depth=10, min_child_weight=105, colsample_bynode=0.24, reg_lambda=0.00485, \
        n_jobs=-1, eta=0.01)
xgboost_classification_model.fit(X_train, y_train, verbose=0)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=0.24,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.01, eval_metric=None,
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#               max_leaves=None, min_child_weight=105, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=2000,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
y_pred = xgboost_classification_model.predict(X_val)

# %%
f1_score(y_val, y_pred, average='micro')
# Out:
# np.float64(0.8115234375)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87       570
#            1       0.77      0.82      0.79       101
#            2       0.77      0.69      0.73       311
#            3       0.56      0.69      0.62        42
#
#     accuracy                           0.81      1024
#    macro avg       0.74      0.77      0.75      1024
# weighted avg       0.81      0.81      0.81      1024

# %%
xgboost_c = XGBClassifier(n_estimators=2000, tree_method='hist', max_depth=10)
xgboost_c.fit(X_train, y_train)
y_pred = xgboost_c.predict(X_val)
f1_score(y_val, y_pred, average='micro')
# Out:
# np.float64(0.814453125)

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

hist_classifier = HistGradientBoostingClassifier()
hist_classifier.fit(X_train, y_train)
y_pred = hist_classifier.predict(X_val)
f1_score(y_val, y_pred, average='micro')
# Out:
# np.float64(0.8193359375)

# %%
from sklearn.ensemble import VotingClassifier

voting = VotingClassifier(estimators=[
    ('xgb_class', xgboost_classification_model), 
    ('hist_class', hist_classifier)
], voting='soft', weights=[0.5, 0.5])

voting.fit(X_train, y_train)
y_pred = voting.predict(X_val)
f1_score(y_val, y_pred, average='micro')
# Out:
# np.float64(0.826171875)

# %%
data_test = pd.read_csv('test_features.csv', header=0, index_col='id')

# %%
X_test = data_test 
X_test.replace(to_replace=np.inf, value=np.nan, inplace=True)

# %%
X_test.columns
# Out:
# Index(['PRinterm', 'PRinterstd', 'PRsegm', 'PRsegstd', 'QRSmean', 'QRSstd',
#        'QTinterm', 'QTinterstd', 'STsegm', 'STsegstd',
#        ...
#        'HRV_LZC', 'HRV_DFA_alpha2', 'HRV_MFDFA_alpha2_Width',
#        'HRV_MFDFA_alpha2_Peak', 'HRV_MFDFA_alpha2_Mean',
#        'HRV_MFDFA_alpha2_Max', 'HRV_MFDFA_alpha2_Delta',
#        'HRV_MFDFA_alpha2_Asymmetry', 'HRV_MFDFA_alpha2_Fluctuation',
#        'HRV_MFDFA_alpha2_Increment'],
#       dtype='object', length=140)

# %%
X_test = X_test.loc[:, mask_multicorr]

# %%
X_filtered_multicorr, y = RandomOverSampler().fit_resample(X_filtered_multicorr, y)

# %%
voting.fit(X_filtered_multicorr, y)
# Out:
# VotingClassifier(estimators=[('xgb_class',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=0.24,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False, eta=0.01,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=10,
#                                             max_leaves=None,
#                                             min_child_weight=105, missing=nan,
#                                             monotone_constraints=None,
#                                             multi_strategy=None,
#                                             n_estimators=2000, n_jobs=-1,
#                                             num_parallel_tree=None, ...)),
#                              ('hist_class', HistGradientBoostingClassifier())],
#                  voting='soft', weights=[0.5, 0.5])

# %%
y_test_pred = voting.predict(X_test)

# %%
sample_submission = pd.DataFrame(y_test_pred, index=data_test.index, columns=['y'])

# %%
sample_submission.to_csv('new_submission.csv')
